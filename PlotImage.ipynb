# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread("148000/148048.jpeg")
print(image.shape)
image = image[:,::-1,:]
plt.imshow(image)
plt.show()
# Out:
# (128, 192, 3)
